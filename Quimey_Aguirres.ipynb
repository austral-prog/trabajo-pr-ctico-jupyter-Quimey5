# %% [markdown]
# ## EJERCICIO 1
# # Quimey Aguirres
# # qaguirres@mail.austral.edu.ar
# ![paisaje.webp](attachment:40d53ffb-1a9d-4def-af47-be77a67825a3.webp)
# montañas y cielo

# %% [raw]
# #hola mucho gusto en conocerte

# %%
a=3
b=7
#sum
a + b
# Out:
# 10

# %%
# substraction
a - b
# Out:
# -4

# %%
#multiplication
a * b
# Out:
# 21

# %%
#division
a / b
# Out:
# 0.42857142857142855
